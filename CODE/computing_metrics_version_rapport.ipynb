# %% [markdown]
# # Description
#
# Notebook to compute metrics.

# %% [markdown]
# # Setup

# %%
# %matplotlib notebook
# %load_ext autoreload

# %% [markdown]
# ## Imports

# %%
# os related
from pathlib import Path
import os 

# data related
import pandas as pd
# import missingno as msno
import datetime as dt
import numpy as np


# visual related
import matplotlib.pyplot as plt
# time related

from fonctions import *

# %% [markdown]
# ## Paths

# %%
# MUST BE IN CODE FOLDER TO WORK !
PROJECT_PATH = Path(os.getcwd()).parent

RAW_DATA = PROJECT_PATH / "RAW_DATA" 
PROC_DATA = PROJECT_PATH / "PROC_DATA"

# RAW FILES
CSV_FILE = RAW_DATA / "Individual_stock_data_csv.csv"
XLSX_FILE = RAW_DATA / "Individual_stock_data.xlsx"

# PROC FILES
PROC_STOCK = PROC_DATA / "proc_stock.csv"
PROC_CARBON = PROC_DATA / "proc_carbon.csv"

STOCK_2000 = PROC_DATA / "stock_2000.csv"

STOCK_WORK = PROC_DATA / "stock_work.csv"
STOCK2USE = PROC_DATA / "stock2use.csv"
DIC2USE = PROC_DATA / "dic2use.json"


OUT_RENDEMENT = PROC_DATA / "rendement_v1.csv"

OUT_DF_CSV = PROC_DATA / "optimize_assets.csv"

# OUT_DIC_WEIGHT = PROC_DATA / "dic_weight.pickle"

# %% [markdown]
# ## Utils

# %%
def compute_enc(weights):
    """Function that computes the ENC for given weights an a given window"""
    return 1 / sum([w**2 for w in weights])
    

def compute_ir(excess_return, track_err):
    """Function that computes the information ratio given 
    the excess return and the track_err"""
    return [ex_ret / track_err for (ex_ret, track_err) in zip(excess_return, track_err)]

def compute_di(weight, stock, vol_p):
    """Function that computes the diversification index"""
    stock_vol = stock.std() * np.sqrt(12)
    return np.dot(stock_vol, weight) / (vol_p * np.sqrt(12))

# %% [markdown]
# # Notebook

# %%
stock_df = read_file(STOCK2USE).iloc[104:-4]

return_df = pd.read_csv(OUT_DF_CSV)
return_df.index = read_file(STOCK2USE).index[104:-4]
return_df.drop(columns="Unnamed: 0", inplace=True)

stock_ret = stock_df.pct_change()

sp500 = read_file(STOCK_WORK)
bm_return = equally_weighted(sp500) 

return_sp = pd.DataFrame((sp500.mean(axis=1).pct_change())*100, columns=["mu"])
return_sp = return_sp.loc[return_df.index[0]:return_df.index[-1]]

# %%
metrics = ["ret", "vol", "sr", 
           "track_err", "yearly_track_error",
           "ex_ret", "enc", "encb", 
           "ir", "di"]

# %%
dic = dict.fromkeys(return_df.columns)
for k in dic.keys():
    dic[k] = dict.fromkeys(metrics)

# %%
# Poids pour chacun des rebalancement
dic_weight = {
    pf: pd.read_csv(PROC_DATA / f"weight_{pf}.csv").rename(columns={'Unnamed: 0':"quarter"}).set_index("quarter")
    for pf in dic.keys()
}

# %%
rf = 0.05

# %%
for pf in dic.keys():
        
    # Rendement annualisé
    dic[pf]["ret"] = return_df[pf].mean() * 52

    # Volatilité sur les 18 ans
    dic[pf]["vol"] = return_df[pf].std() * np.sqrt(52)
    
    # Ratio de sharp
    dic[pf]["sr"] = (dic[pf]["ret"] - rf) / dic[pf]["vol"]
    
     # Tracking error
    dic[pf]["track_err"] = []
    for i in range(len(return_df)//12): # par paquet de 3 mois
        dic[pf]["track_err"].append((return_df[pf].iloc[i*12:(i+1)*12] - return_sp["mu"].iloc[i*12:(i+1)*12]).std())
    
    # Tracking global error
    dic[pf]["yearly_track_err"] = []
    for i in range(len(return_df)//(12*4)): # par paquet de 1 an
        dic[pf]["yearly_track_err"].append((return_df[pf].iloc[i*12*4:(i+1)*12*4] - return_sp["mu"].iloc[i*12*4:(i+1)*12*4]).std())
    
    # Excess return 
    dic[pf]["ex_ret"] = []
    for i in range(len(return_df)//12): # par paquet de 3 mois
        dic[pf]["ex_ret"].append( 
            (return_df[pf].iloc[i*12:(i+1)*12].mean()) - (return_sp["mu"].iloc[i*12:(i+1)*12].mean())
        )
        
    # Yearly Excess return 
    dic[pf]["yearly_ex_ret"] = []
    for i in range(len(return_df)//(12*4)): # par paquet de 1 an
        dic[pf]["yearly_ex_ret"].append( 
            (return_df[pf].iloc[i*12*4:(i+1)*12*4].mean()) - (return_sp["mu"].iloc[i*12*4:(i+1)*12*4].mean())
        )

    # Calcul de l'ENC
    dic[pf]["enc"] = dic_weight[pf].apply(compute_enc, axis=1)
    
    # Information ratio
    dic[pf]["ir"] = compute_ir(dic[pf]["ex_ret"], dic[pf]["track_err"])
        
    # Yearly Information ratio
    dic[pf]["yearly_ir"] = compute_ir(dic[pf]["yearly_ex_ret"],
                                             dic[pf]["yearly_track_err"])
    
    # Diversification index # récupérer les poids
    sum_di = 0
    for i in range(len(return_df)//12):
          sum_di += compute_di(
            weight=dic_weight[pf].iloc[i],
            stock=stock_ret.iloc[i*12:(i+1)*12],
            vol_p=return_df[pf].iloc[i*12:(i+1)*12].std())
            
    print(pf)
    print(sum_di)
    dic[pf]["di"] = sum_di / (len(return_df)//12)
# Out:
# ew
# 1.5161281619472564
# gmv
# 0.9725269264584693
# maxdecor
# 1.301979332731861
# maxdiv
# 1.1439020886895856
# msr
# 1.0421172284966664

# %%
dic
# Out:
# {'ew': {'ret': 15.46086914246365,
#   'vol': 16.89877855411223,
#   'sr': 0.9119516592939491,
#   'track_err': [1.1829968686588939,
#    1.0892322732695137,
#    1.0300149369949683,
#    1.0675947845438125,
#    1.1061082875118267,
#    0.999318143388918,
#    1.7556428002255908,
#    1.04767495732451,
#    1.0267810381440654,
#    1.4279007185784265,
#    1.1749534211232748,
#    1.0359679719927715,
#    1.556927449441648,
#    1.2136624093101513,
#    0.800790996902656,
#    1.4339465290650826,
#    1.1994873823298764,
#    0.958063023175989,
#    1.4319804269286607,
#    1.9056979397108424,
#    1.2085487867012756,
#    1.4930692562573369,
#    1.6414964632873643,
#    0.9735427078915739,
#    1.9974057408920471,
#    2.4880308096024413,
#    2.0798290596596885,
#    1.9379963834741978,
#    2.7996193621652314,
#    2.378354574049002,
#    3.26212165952714,
#    1.6907606580564634,
#    1.8271694557527225,
#    1.8818142268651699,
#    1.836526544311918,
#    1.1624397977126917,
#    1.4459614459105785,
#    1.397463346492769,
#    1.0901508546497032,
#    1.1638875334000018,
#    1.4780083328243907,
#    0.9008351049530319,
#    1.9600130310351214,
#    1.4931396572764242,
#    0.1641624446431167,
#    0.23706062425808097,
#    -0.11609945689382416,
#    -0.789253041485645,
#    0.3284357443778388,
#    -0.016265323522211675,
#    -0.7460061626575611,
#    -0.020591591218854104,
#    -0.2556071245997528,
#    0.32820686571041574,
#    -0.09001468739228659,
#    0.052367948674931865,
#    0.38084655809098444,
#    -0.17330390788134503,
#    0.1948765838005222,
#    0.12913181564156948,
#    -0.2762213394569285,
#    -0.09501867983301536,
#    0.28662744913509314,
#    -0.22199249566728702,
#    0.31028125870696166,
#    0.347646026529184,
#    0.26375705461592913,
#    0.3742579538608883,
#    0.10181096694209323,
#    -0.2580126126751236,
#    -0.33338063385161343,
#    -0.1357358197690266,
#    -0.26343622357179036,
#    -0.2151910611134985,
#    0.4642577248486532,
#    -0.2422665571227095,
#    -0.353577796123088,
#    0.31638649915866157,
#    -0.36005760768905315,
#    -0.06064396635370338,
#    0.11211007679476152],
#   'di': 0.0133604772884188,
#   'yearly_track_err': [2.559917525670701,
#    2.5446706335936424,
#    1.9312891004652586,
#    2.3499825352304624,
#    2.248158118941564,
#    2.2619064200962584,
#    3.550491155354031,
#    4.680892969811263,
#    3.0233086374775335,
#    2.265219901170442,
#    2.435671922598766,
#    2.5200979642684955,
#    2.0763527569248503,
#    2.314797518335141,
#    1.8210504796149052,
#    2.2882230564654917,
#    1.8738163242198136,
#    2.297483414023364,
#    1.6928668579825776],
#   'yearly_ex_ret': [0.5116464876649596,
#    0.3309829413410743,
#    -0.05533672962128727,
#    -0.42692538665309054,
#    0.045724299535715995,
#    0.23926967263726118,
#    0.5717357606418573,
#    -0.26049613774762326,
#    -0.5495970939600486,
#    0.054434081452718275,
#    0.20187595464337268,
#    -0.6634325097144046,
#    0.00347830756305878,
#    0.2752973825331987,
#    0.02020671568476501,
#    0.3264078124636697,
#    -0.146348457442913,
#    -0.12267236830085224,
#    -0.20826405881991494],
#   'yearly_ir': [0.19986834830974004,
#    0.13006906943931387,
#    -0.028652742672216364,
#    -0.18167172745018806,
#    0.02033856033099801,
#    0.10578230403850163,
#    0.16103004785118177,
#    -0.055650949386720674,
#    -0.181786631754077,
#    0.024030374015605337,
#    0.08288306514942251,
#    -0.26325663490902346,
#    0.0016752006861349865,
#    0.11892935790392556,
#    0.011096186465428511,
#    0.14264685059500107,
#    -0.07810181582436954,
#    -0.05339423455772757,
#    -0.12302447640100136]}}

# %%
# %store dic
# Out:
# Stored 'dic' (dict)

# %%
dic["ew"].keys()
# Out:
# dict_keys(['ret', 'vol', 'sr', 'track_err', 'yearly_track_error', 'ex_ret', 'enc', 'encb', 'ir', 'di', 'yearly_track_err', 'yearly_ex_ret', 'yearly_ir'])

# %%
dic.keys()
# Out:
# dict_keys(['ew', 'gmv', 'maxdecor', 'maxdiv', 'msr'])

# %%
dic[k]["ret"]
# Out:
# 12.305292959206094

# %%
plt.figure()
plt.bar(dic.keys(),
    [dic[k]["ret"] for k in dic.keys()],
       align="center",
        width=0.4
   )

plt.title("Rendement par portefeuille", fontsize=15)
plt.ylabel("%", fontsize=15)
plt.ylim(0,22)

plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
# Out:
# <div id='b6729586-6fe3-43ef-a5de-bb55c230b51e'></div>
# (array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5]),
#  <a list of 10 Text yticklabel objects>)

# %%
fig, axs = plt.subplots(1, len(dic.keys())+1, sharex=True, 
                        sharey=True,
                        figsize=(9, 6),
                        gridspec_kw={"width_ratios": [3, 3, 3, 3, 3, 1]})

dic_color = {'increasing':'green', 'decreasing':'red', 'no trend':'blue'}


labels = list(dic.keys())

for i, col in enumerate(return_df.columns):
    axs[i].hist(return_df[col], bins=50, density=True)
    axs[i].set_xlabel("%")
    axs[i].set_title(col, fontsize=11, pad=0.5)
    axs[i].grid(True)
    

    
lax = axs[-1]
lax.axis('off')
# lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in dic_color.values()]
#lax.legend(lines, labels, loc=10, fontsize=9)

# ----------------

fig.suptitle("Distribution des rendements hebdomadaires (%)")
#fig.suptitle("From {} to {})".format(start, end))
#fig.tight_layout(rect=[0,0,1,0.98])
# Out:
# <div id='a47a0594-b802-4fd4-98c6-c3400b557ff7'></div>
# Text(0.5, 0.98, 'Distribution des rendements hebdomadaires (%)')

# %%
plt.figure()
plt.bar(dic.keys(),
    [dic[k]["vol"] for k in dic.keys()],
       align="center",
        width=0.4)

plt.title("Ecart-Type par portefeuille", fontsize=15)
plt.ylabel("%", fontsize=15)

plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
# Out:
# <div id='19380815-24a4-42b1-909e-739dac7554da'></div>
# (array([ 0.,  5., 10., 15., 20., 25.]), <a list of 6 Text yticklabel objects>)

# %% [markdown]
# Distribution des rendements

# %% [markdown]
# ## Tracking error

# %%
yr_idx = [str(i) for i in range(2001,2020)]

track_error_df = pd.DataFrame(index=yr_idx)

for k in dic.keys():
    track_error_df[k] = dic[k]["yearly_track_err"]
    
    

track_error_df.plot()    
plt.title("Tracking Error annuelle")
# Out:
# <div id='7ca7987c-3371-4372-a8b7-d9d66bf8ef2a'></div>
# Text(0.5, 1.0, 'Tracking Error annuelle')

# %%
plt.figure()
for k in dic.keys():
    plt.plot(dic[k]["yearly_track_err"], label=k)
    plt.legend()
    
plt.title("Tracking Error annuelle")

ticks = [i for i in range(19)]
x_labels = [i for i in range(2001,2020)]

plt.xticks(xticks=range(19),
labels=x_labels)

plt.show()
# Out:
# <div id='c6bd94da-9f53-438f-a676-52999d161fd7'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8650b69f3ac8> in <module>
#      10
#      11 plt.xticks(xticks=range(19),
# ---> 12 labels=x_labels)
#      13
#      14 plt.show()
#
# D:\logiciel\Anaconda\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1541         labels = ax.get_xticklabels()
#    1542     else:
# -> 1543         locs = ax.set_xticks(ticks)
#    1544         labels = ax.set_xticklabels(labels, **kwargs)
#    1545     for l in labels:
#
# D:\logiciel\Anaconda\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    3348             Default is ``False``.
#    3349         """
# -> 3350         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    3351         self.stale = True
#    3352         return ret
#
# D:\logiciel\Anaconda\lib\site-packages\matplotlib\axis.py in set_ticks(self, ticks, minor)
#    1750         # XXX if the user changes units, the information will be lost here
#    1751         ticks = self.convert_units(ticks)
# -> 1752         if len(ticks) > 1:
#    1753             xleft, xright = self.get_view_interval()
#    1754             if xright > xleft:
#
# TypeError: object of type 'NoneType' has no len()

# %%
fig, axs = plt.subplots(1, len(dic.keys())+1, sharex=True, 
                        sharey=True,
                        figsize=(9, 6),
                        gridspec_kw={"width_ratios": [3, 3, 3, 3, 3, 1]})

dic_color = {'increasing':'green', 'decreasing':'red', 'no trend':'blue'}


labels = list(dic.keys())

for i, col in enumerate(return_df.columns):
    axs[i].hist(dic[col]["track_err"], bins=15)
    axs[i].set_xlabel("%")
    axs[i].set_title(f"{col}", fontsize=11, pad=0.5)
    axs[i].grid(True)
    

    
lax = axs[-1]
lax.axis('off')
# lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in dic_color.values()]
#lax.legend(lines, labels, loc=10, fontsize=9)

# ----------------

fig.suptitle("Distribution des tracking error hebdomadaires (%)")
#fig.suptitle("From {} to {})".format(start, end))
#fig.tight_layout(rect=[0,0,1,0.98])
# Out:
# <img src="data:image/png;base64,..." width="900">
# Text(0.5, 0.98, 'Distribution des tracking error hebdomadaires (%)')

# %% [markdown]
# excess return

# %%
yr_idx = [str(i) for i in range(2001,2020)]

ex_ret_df = pd.DataFrame(index=yr_idx)

for k in dic.keys():
    ex_ret_df[k] = dic[k]["yearly_ex_ret"]
    
    

ex_ret_df.plot()    
plt.title("Excess Return  annuel")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Excess Return  annuel')

# %%
ex_ret_df
# Out:
#             ew       gmv  maxdecor    maxdiv       msr
# 2001  0.087545  0.423809  0.290996  0.511646  0.511646
# 2002 -0.030390 -0.144771  0.277967  0.330983  0.330983
# 2003  0.100957  0.152672  0.318134 -0.055337 -0.055337
# 2004 -0.072290 -0.358647 -0.399250 -0.426925 -0.426925
# 2005  0.069528  0.000567  0.206872  0.045724  0.045724
# 2006 -0.086441 -0.016954 -0.040967  0.239270  0.239270
# 2007  0.330304  0.114159  0.109015  0.571736  0.571736
# 2008 -0.004782 -0.228960 -0.237260 -0.260496 -0.260496
# 2009 -0.183223  0.816974 -0.438276 -0.549597 -0.549597
# 2010  0.131860  0.363062 -0.237441  0.054434  0.054434
# 2011  0.270251  0.084156  0.048777  0.201876  0.201876
# 2012 -0.245633 -0.112577 -0.981436 -0.663433 -0.663433
# 2013  0.094405 -0.015677  0.005893  0.003478  0.003478
# 2014  0.065298  0.048158  0.184951  0.275297  0.275297
# 2015  0.220607  0.029341 -0.108724  0.020207  0.020207
# 2016  0.248115  0.627015  0.289892  0.326408  0.326408
# 2017 -0.013202 -0.249754  0.097054 -0.146348 -0.146348
# 2018  0.248333  0.133147  0.017999 -0.122672 -0.122672
# 2019 -0.024287 -0.194412 -0.113985 -0.208264 -0.208264

# %%
ex_ret_df.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
#     #T_5ddfd126_3126_11ed_9f8c_4023435ff324row0_col0 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row0_col1 {
#             background-color:  #3787c0;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row0_col2 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row0_col3 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row0_col4 {
#             background-color:  #083c7d;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row1_col0 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row1_col1 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row1_col2 {
#             background-color:  #083776;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row1_col3 {
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row1_col4 {
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row2_col0 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row2_col1 {
#             background-color:  #85bcdc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row2_col3 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row2_col4 {
#             background-color:  #6dafd7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row3_col0 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row3_col2 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row3_col3 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row3_col4 {
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row4_col0 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row4_col1 {
#             background-color:  #b4d3e9;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row4_col2 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row4_col3 {
#             background-color:  #539ecd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row4_col4 {
#             background-color:  #539ecd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row5_col0 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row5_col1 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row5_col2 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row5_col3 {
#             background-color:  #2575b7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row5_col4 {
#             background-color:  #2575b7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row6_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row6_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row6_col2 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row6_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row6_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row7_col0 {
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row7_col1 {
#             background-color:  #e1edf8;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row7_col2 {
#             background-color:  #539ecd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row7_col3 {
#             background-color:  #aed1e7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row7_col4 {
#             background-color:  #aed1e7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row8_col0 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row8_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row8_col2 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row8_col3 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row8_col4 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row9_col0 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row9_col1 {
#             background-color:  #4594c7;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row9_col2 {
#             background-color:  #539ecd;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row9_col3 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row9_col4 {
#             background-color:  #519ccc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row10_col0 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row10_col1 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row10_col2 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row10_col3 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row10_col4 {
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row11_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row11_col1 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row11_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row11_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_5ddfd126_3126_11ed_9f8c_4023435ff324row11_col4 {
#             background-color:  #f7fbff;
#             color:  #0

# %%
yr_idx = [str(i) for i in range(len(dic["ew"]["enc"]))]

enc_df = pd.DataFrame(index=yr_idx)

for k in list(dic.keys())[1:]:
    enc_df[k] = dic[k]["enc"].values
    
    

enc_df.plot()    
plt.title("Evolution Trimestirelle de l'ENC")
plt.xlabel("Trismestre")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'Trismestre')

# %% [markdown]
# Information ratio

# %%
yr_idx = [str(i) for i in range(2001,2020)]

ir_df = pd.DataFrame(index=yr_idx)

for k in dic.keys():
    ir_df[k] = dic[k]["yearly_ir"]

ir_df.plot()    
plt.title("Information Ratio annuel")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Information Ratio annuel')

# %%
ir_df.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
#     #T_7d3e3206_3114_11ed_b072_4023435ff324row0_col0 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row0_col1 {
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row0_col2 {
#             background-color:  #084285;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row1_col0 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row1_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row1_col2 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row1_col3 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row1_col4 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row2_col0 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row2_col1 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row2_col3 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row2_col4 {
#             background-color:  #69add5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row3_col0 {
#             background-color:  #bfd8ed;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row3_col2 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row3_col3 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row3_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row4_col0 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row4_col1 {
#             background-color:  #9cc9e1;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row4_col2 {
#             background-color:  #084184;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row4_col3 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row4_col4 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row5_col0 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row5_col1 {
#             background-color:  #a1cbe2;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row5_col2 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row5_col3 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row5_col4 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row6_col0 {
#             background-color:  #206fb4;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row6_col1 {
#             background-color:  #72b2d8;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row6_col2 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row6_col3 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row6_col4 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row7_col0 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row7_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row7_col2 {
#             background-color:  #4a98c9;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row7_col3 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row7_col4 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row8_col0 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row8_col1 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row8_col2 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row8_col3 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row8_col4 {
#             background-color:  #d4e4f4;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row9_col0 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row9_col1 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row9_col2 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row9_col3 {
#             background-color:  #4493c7;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row9_col4 {
#             background-color:  #4493c7;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row10_col0 {
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row10_col1 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row10_col2 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row10_col3 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row10_col4 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row11_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row11_col1 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row11_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row11_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_7d3e3206_3114_11ed_b072_4023435ff324row11_col4 {
#             background-color:  #f7fbff;
#             color:  #0

# %% [markdown]
# sharp ratio

# %%
plt.figure()
plt.bar(dic.keys(),
    [dic[k]["sr"] for k in dic.keys()],
       align="center",
        width=0.4)

plt.title("Sharp Ratio par portefeuille", fontsize=15)
plt.ylabel("%", fontsize=15)

plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text yticklabel objects>)

# %% [markdown]
# ### analysis

# %% [markdown]
# - Récupérer table de poids
# - Calculer poids moyen sur les 20 ans
# - Analyser les 3 plus gros poids pour les 5 portefeuilles

# %%
path = f"weight_{w}.csv"
df = pd.read_csv(PROC_DATA / path)
df.mean().sort_values(ascending=False)[1:4]
# Out:
# pld     0.477815
# viac    0.198780
# el      0.091112
# dtype: float64

# %%
# Itérer sur les 5 portefeuille

for w in dic.keys():
    plt.figure()    
    path = f"weight_{w}.csv"
    df = pd.read_csv(PROC_DATA / path)
    print(w.upper())
    print(df.mean().sort_values(ascending=False)[1:4], "\n")
    top_assets = df.mean().sort_values(ascending=False)[1:4].index.tolist()
    df.drop(columns='Unnamed: 0', inplace=True)
    
    
    plt.plot(df.loc[:, ~df.columns.isin([top_assets])], color="black", alpha=0.2)
    plt.plot(df[top_assets], color="salmon")
    plt.title(f" {w.upper()} : Evolution des poids dans le temps")
    plt.ylim(0,1.2)
    
    
#     plt.figure()    
#     plt.plot(stock_ret.loc[:, stock_ret.columns.isin([df.columns])], color="black", alpha=0.2)
#     plt.plot(stock_ret[top_assets], color="salmon")
#     plt.title(f" {w.upper()} : Evolution des rendements dans le temps")
#     # plt.ylim(0,1.2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# EW
# unh    0.02
# slb    0.02
# bkr    0.02
# dtype: float64
# <img src="data:image/png;base64,..." width="640">
# GMV
# pld     0.474084
# el      0.172455
# viac    0.168027
# dtype: float64
# <img src="data:image/png;base64,..." width="640">
# MAXDECOR
# exc    0.075090
# ed     0.063482
# hal    0.053370
# dtype: float64
# <img src="data:image/png;base64,..." width="640">
# MAXDIV
# bkr    0.125380
# hal    0.109728
# exc    0.085999
# dtype: float64
# <img src="data:image/png;base64,..." width="640">
# MSR
# pld     0.477815
# viac    0.198780
# el      0.091112
# dtype: float64

# %% [markdown]
# Spider plot

# %%
kpi_list = ["ret", "enc", "vol", "ex_ret", "track_err"]

# %%
import plotly.graph_objects as go



for k in dic.keys():
    values = [np.mean(dic[k][kpi]) for kpi in kpi_list]
    
    values[3] *= 10
    values[4] *= 10
    

    fig = go.Figure(data=go.Scatterpolar(
      r=values,
      theta=kpi_list,
      fill='toself'
    ))

    fig.update_layout(
      polar=dict(
        radialaxis=dict(
          visible=True
        ),
      ),
      showlegend=False
    )

    
    fig.show()
# Out:
# <div>                            <div id="f5e21a71-6f43-44f1-8254-2c74fff74b82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5e21a71-6f43-44f1-8254-2c74fff74b82")) {                    Plotly.newPlot(                        "f5e21a71-6f43-44f1-8254-2c74fff74b82",                        [{"fill":"toself","r":[15.46086914246365,50.0,16.89877855411223,0.7158656679133996,13.078200198619282],"theta":["ret","enc","vol","ex_ret","track_err"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scatter ...
#
# var gd = document.getElementById('f5e21a71-6f43-44f1-8254-2c74fff74b82');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle
# <div>                            <div id="03819c2b-7244-412a-acd7-9b80b858ded2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03819c2b-7244-412a-acd7-9b80b858ded2")) {                    Plotly.newPlot(                        "03819c2b-7244-412a-acd7-9b80b858ded2",                        [{"fill":"toself","r":[15.76867430474142,1.9280221047905037,23.555237698682696,0.775058968351434,24.398524590610545],"theta":["ret","enc","vol","ex_ret","track_err"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{" ...
#
# var gd = document.getElementById('03819c2b-7244-412a-acd7-9b80b858ded2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.ge
# <div>                            <div id="0b454338-b04c-4d11-a4aa-cf40eb0b3392" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b454338-b04c-4d11-a4aa-cf40eb0b3392")) {                    Plotly.newPlot(                        "0b454338-b04c-4d11-a4aa-cf40eb0b3392",                        [{"fill":"toself","r":[10.074823209421256,5.117514161501741,19.570433415942833,-0.3199123961332176,20.47717798883426],"theta":["ret","enc","vol","ex_ret","track_err"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{ ...
#
# var gd = document.getElementById('0b454338-b04c-4d11-a4aa-cf40eb0b3392');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.g
# <div>                            <div id="3946a7e9-d616-4ffc-9d48-3b35a59c0b70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3946a7e9-d616-4ffc-9d48-3b35a59c0b70")) {                    Plotly.newPlot(                        "3946a7e9-d616-4ffc-9d48-3b35a59c0b70",                        [{"fill":"toself","r":[12.305292959206094,3.1239398375657923,20.12849851310934,0.10902409421001873,24.052928033858684],"theta":["ret","enc","vol","ex_ret","track_err"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[ ...
#
# var gd = document.getElementById('3946a7e9-d616-4ffc-9d48-3b35a59c0b70');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.
# <div>                            <div id="a3e30bf4-1d89-47cb-bf82-50c4e4981709" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3e30bf4-1d89-47cb-bf82-50c4e4981709")) {                    Plotly.newPlot(                        "a3e30bf4-1d89-47cb-bf82-50c4e4981709",                        [{"fill":"toself","r":[12.305292959206094,1.568679686422257,20.12849851310934,0.10902409421001873,24.052928033858684],"theta":["ret","enc","vol","ex_ret","track_err"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{ ...
#
# var gd = document.getElementById('a3e30bf4-1d89-47cb-bf82-50c4e4981709');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.g
